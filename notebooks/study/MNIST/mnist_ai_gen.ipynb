# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms

transform = transforms.ToTensor()
train_data = datasets.MNIST(root="./data", train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)

print(f"训练集大小: {len(train_data)}")
print(f"每张图形状: {train_data[0][0].shape}")
# Out:
# 训练集大小: 60000
# 每张图形状: torch.Size([1, 28, 28])

# %% [markdown]
# 下载训练图

# %%
class MNISTModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.Linear(784, 128),
            nn.ReLU(),
            nn.Linear(128, 16),
            nn.ReLU(),
            nn.Linear(16, 10),
        )

    def forward(self, x):
        return self.net(x)

model = MNISTModel()

# %% [markdown]
# Cell 2

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.06)

for epoch in range(5):
    total_loss = 0
    correct = 0
    total = 0
    for images, labels in train_loader:
        pre_d: torch.Tensor = model(images)
        loss = loss_fn(pre_d, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        total += len(labels)
        correct += (pre_d.argmax(1) == labels).sum().item()
    print(f"Epoch {epoch+1}  Loss: {total_loss/len(train_loader):.2f} Accuracy:{correct/total:.4f}")
# Out:
# Epoch 1  Loss: 0.67 Accuracy:0.8033
# Epoch 2  Loss: 0.27 Accuracy:0.9235
# Epoch 3  Loss: 0.19 Accuracy:0.9460
# Epoch 4  Loss: 0.15 Accuracy:0.9574
# Epoch 5  Loss: 0.12 Accuracy:0.9662

# %% [markdown]
# Cell 3

# %% [markdown]
# **Generated by Deepseek-v4-pro**
