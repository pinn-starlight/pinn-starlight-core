# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms

transform = transforms.ToTensor()
train_data = datasets.MNIST(root="./data", train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)

print(f"训练集大小: {len(train_data)}")
print(f"每张图形状: {train_data[0][0].shape}")
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%
# 训练集大小: 60000
# 每张图形状: torch.Size([1, 28, 28])

# %% [markdown]
# 下载训练图

# %%
class MNISTModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.Linear(784, 16),
            nn.ReLU(),
            nn.Linear(16, 16),
            nn.ReLU(),
            nn.Linear(16, 10),
        )

    def forward(self, x):
        return self.net(x)

model = MNISTModel()
print(model)
# Out:
# MNISTModel(
#   (net): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=784, out_features=16, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=16, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=16, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# Cell 2

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

for epoch in range(20):
    total_loss = 0
    for images, labels in train_loader:
        pre_d = model(images)
        loss = loss_fn(pre_d, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"Epoch {epoch+1}  Loss: {total_loss:.2f}")
# Out:
# Epoch 1  Loss: 535.90
# Epoch 2  Loss: 265.89
# Epoch 3  Loss: 218.03
# Epoch 4  Loss: 189.06
# Epoch 5  Loss: 171.24
# Epoch 6  Loss: 157.45
# Epoch 7  Loss: 147.57
# Epoch 8  Loss: 138.65
# Epoch 9  Loss: 132.05
# Epoch 10  Loss: 126.39
# Epoch 11  Loss: 121.90
# Epoch 12  Loss: 117.66
# Epoch 13  Loss: 113.08
# Epoch 14  Loss: 110.16
# Epoch 15  Loss: 106.88
# Epoch 16  Loss: 104.81
# Epoch 17  Loss: 101.70
# Epoch 18  Loss: 99.50
# Epoch 19  Loss: 96.63
# Epoch 20  Loss: 95.22

# %% [markdown]
# Cell 3

# %% [markdown]
# **Generated by Deepseek-v4-pro**
